# %%
import matplotlib.pyplot as plt
import eland as ed
import numpy as np

# Remove pandas/matplotlib deprecation warning
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

# %matplotlib inline

# %%
ed_df = ed.DataFrame('localhost', 'flights')

# %%
ed_df[ed_df.OriginWeather == 'Sunny']['FlightTimeMin'].hist(alpha=0.5, density=True)
# Out:
# <AxesSubplot:>

# %%
ed_df[ed_df.OriginWeather != 'Sunny']['FlightTimeMin'].hist(alpha=0.5, density=True)
# Out:
# <AxesSubplot:>

# %%
ed_df.select_dtypes(include=[np.number]).hist(figsize=[10,10])
# Out:
# array([[<AxesSubplot:title={'center':'AvgTicketPrice'}>,
#         <AxesSubplot:title={'center':'DistanceKilometers'}>,
#         <AxesSubplot:title={'center':'DistanceMiles'}>],
#        [<AxesSubplot:title={'center':'FlightDelayMin'}>,
#         <AxesSubplot:title={'center':'FlightTimeHour'}>,
#         <AxesSubplot:title={'center':'FlightTimeMin'}>],
#        [<AxesSubplot:title={'center':'dayOfWeek'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)
