# %%
from eland.tests.common import TestData

test_data = TestData()

pd_flights = test_data.pd_flights()[['DistanceKilometers', 'DistanceMiles', 'FlightDelayMin', 'FlightTimeHour']]
ed_flights = test_data.ed_flights()[['DistanceKilometers', 'DistanceMiles', 'FlightDelayMin', 'FlightTimeHour']]

# %%
pd_flights.hist(figsize=[10,10])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11e26a630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e2734e0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e264a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e2725f8>]],
#       dtype=object)

# %%
ed_flights.hist(figsize=[10,10])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11dfd07f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11dfaf9e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11e14d5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11e3ef4e0>]],
#       dtype=object)

# %%
test_data.pd_flights().hist()
# Out:
# RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/envs/eland/lib/python3.6/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     341     try:
# --> 342         dt = signed_to_unsigned[dt.type]
#     343     except KeyError:
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-a8a6dc53a547> in <module>
#       1
# ----> 2 test_data.pd_flights().hist()
#       3
#
# /anaconda3/envs/eland/lib/python3.6/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, **kwds)
#    2408     for i, col in enumerate(com.try_sort(data.columns)):
#    2409         ax = _axes[i]
# -> 2410         ax.hist(data[col].dropna().values, bins=bins, **kwds)
#    2411         ax.set_title(col)
#    2412         ax.grid(grid)
#
# /anaconda3/envs/eland/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# /anaconda3/envs/eland/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6751             # this will automatically overwrite bins,
#    6752             # so that each histogram uses the same bins
# -> 6753             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6754             m = m.astype(float)  # causes problems later if it's an int
#    6755             if mlast is None:
#
# /anaconda3/envs/eland/lib/python3.6/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     808
#     809         # Pre-compute histogram scaling factor
# --> 810         norm = n_equal_bins / _unsigned_subtract(last_edge, first_edge)
#     811
#     812         # We iterate over blocks here for two reasons: the first is that for
#
# /anaconda3/envs/eland/lib/python3.6/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     342         dt = signed_to_unsigned[dt.type]
#     343     except KeyError:
# --> 344         return np.subtract(a, b, dtype=dt)
#     345     else:
#     346         # we know the inputs are integers, and we are deliberately casting
#
# TypeError: numpy boolean subtract, the `-` operator, is deprecated, use the bitwise_xor, the `^` operator, or the logical_xor function instead.
