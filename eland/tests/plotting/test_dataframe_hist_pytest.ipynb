# %%
from eland.tests.common import TestData
import matplotlib.pyplot as plt

test_data = TestData()

pd_flights = test_data.pd_flights()[['DistanceKilometers', 'DistanceMiles', 'FlightDelayMin', 'FlightTimeHour']]
ed_flights = test_data.ed_flights()[['DistanceKilometers', 'DistanceMiles', 'FlightDelayMin', 'FlightTimeHour']]
# Out:
# In Index.__next__

# %%
pd_flights.hist(figsize=[10,10])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1242f2b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124143358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x124329a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124b33b70>]],
#       dtype=object)

# %%
ed_flights.hist(figsize=[10,10])
# Out:
# Empty DataFrame
# Columns: [DistanceKilometers, DistanceMiles, FlightDelayMin, FlightTimeHour]
# Index: []
