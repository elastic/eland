# %%
import matplotlib.pyplot as plt

from eland.tests.common import TestData

test_data = TestData()

pd_flights = test_data.pd_flights()[['DistanceKilometers', 'DistanceMiles', 'FlightDelayMin', 'FlightTimeHour']]
ed_flights = test_data.ed_flights()[['DistanceKilometers', 'DistanceMiles', 'FlightDelayMin', 'FlightTimeHour']]

# %%
pd_flights.hist(figsize=[10,10])

plt.show()

# %%
ed_flights.hist(figsize=[10,10])

plt.show()

# %% [markdown]
# Change flight columns

# %%
ed_flights = test_data.ed_flights()[['AvgTicketPrice','DistanceKilometers', 'DistanceMiles', 'FlightDelayMin', 'FlightTimeHour']]

ed_flights.hist(figsize=[10,10])

plt.show()

# %%
print(ed_flights.columns)

ed_flights[ed_flights.AvgTicketPrice > 500 & ed_flights.DestWeather == 'Clear'].hist(figsize=[10,10])
# Out:
# Index(['AvgTicketPrice', 'DistanceKilometers', 'DistanceMiles',
#        'FlightDelayMin', 'FlightTimeHour'],
#       dtype='object')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-805013789d8a> in <module>
#       2 print(ed_flights.columns)
#       3
# ----> 4 ed_flights[ed_flights.AvgTicketPrice > 500 & ed_flights.DestWeather == 'Clear'].hist(figsize=[10,10])
#
# ~/PycharmProjects/eland/eland/ndframe.py in __getattr__(self, key)
#     100             if key in self.columns:
#     101                 return self[key]
# --> 102             raise e
#     103
#     104     def __sizeof__(self):
#
# ~/PycharmProjects/eland/eland/ndframe.py in __getattr__(self, key)
#      96         """
#      97         try:
# ---> 98             return object.__getattribute__(self, key)
#      99         except AttributeError as e:
# ...

# %%
ed_flights[ed_flights.AvgTicketPrice > 400].describe()
# Out:
#        AvgTicketPrice  DistanceKilometers  DistanceMiles  FlightDelayMin  \
# count     9911.000000         9911.000000    9911.000000     9911.000000
# mean       741.767698         7869.026973    4889.586667       47.196045
# std        194.441174         4232.118944    2629.716791       96.912496
# min        400.041290            0.000000       0.000000        0.000000
# 25%        580.761133         5761.941846    3587.218914        0.000000
# 50%        738.507419         7997.826941    4969.496396        0.000000
# 75%        891.883046        10117.475424    6284.638106        9.095745
# max       1199.729004        19881.482422   12353.780273      360.000000
#
#        FlightTimeHour
# count     9911.000000
# mean         9.362701
# std          5.294526
# min          0.000000
# 25%          6.075868
# 50%          9.033861
# 75%         12.505971
# max         31.715034

# %%
ed_flights[ed_flights.DistanceKilometers.isna()]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-24-d42dcf13a0d9> in <module>
# ----> 1 ed_flights[ed_flights.DistanceKilometers.isna()]
#       2
#       3
#
# /anaconda3/envs/eland/lib/python3.6/site-packages/modin/pandas/base.py in isna(self)
#    1401             False: otherwise.
#    1402         """
# -> 1403         return self.__constructor__(query_compiler=self._query_compiler.isna())
#    1404
#    1405     isnull = isna
#
# /anaconda3/envs/eland/lib/python3.6/site-packages/modin/backends/base/query_compiler.py in isna(self)
#     375
#     376     def isna(self):
# --> 377         raise NotImplementedError("Must be implemented in children classes")
#     378
#     379     def isnull(self):
#
# NotImplementedError: Must be implemented in children classes
